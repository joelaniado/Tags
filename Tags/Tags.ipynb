# %%
import sys
import glob, os, os.path
from docx.oxml.ns import nsdecls
from docx.oxml import parse_xml
#!{sys.executable} -m pip install pillow

# %%
import docx
import pandas as pd
from docx.shared import Pt
from docx.enum.table import WD_TABLE_ALIGNMENT
from docx.enum.table import WD_ALIGN_VERTICAL
from docx.enum.section import WD_SECTION
from docx.shared import Cm, Inches

import barcode
from barcode import UPCA 
from barcode.writer import ImageWriter

# %%
# Disables writing under barcode image
barcode.base.Barcode.default_writer_options['write_text'] = False

# Generates barcode and saves into folder
def generate_barcode(number):
    upc = str(number)

    # Important to specify UPC type
    my_code = UPCA(upc, writer=ImageWriter()) 
    my_code.save('Barcodes/'+ upc)

# %%
#Sets Margins for each table in the document
def set_section_margins(doc):
    sections = doc.sections
    for section in sections:
        section.top_margin = Inches(0.5)  # Set top margin to 1 inch
        section.bottom_margin = Inches(0.42)  # Set bottom margin to 1 inch
        section.left_margin = Inches(0.56)  # Set left margin to 1.25 inches
        section.right_margin = Inches(0.31)

# %%
#Sets dimensions for each printable section in table

def set_table_dim(table):
    for row in table.rows:
        row.height = Inches(1.245)
    index = 1
    for column in table.columns:
        for cell in column.cells:
            if index%2==0:
                cell.width = Inches(0.2)
            else:
                cell.width = Inches(1.75)
        index+=1

# %%
# Populates table with data available in excel document
def populate_table(table,df):
    
    data_index = 0
    max_index = df.shape[0]
    counter = 1
    print(len(table.rows))
    for row in table.rows:
        for cell in row.cells:
            shading_elm_1 = parse_xml(r'<w:shd {} w:fill="FF7F7F"/>'.format(nsdecls('w')))
            if counter%2!=0 and data_index < max_index:
                name = df.loc[data_index,'Description1']
                price = df.loc[data_index,'Price']
                barcode = df.loc[data_index,'Barcode Lookup']
                cell.vertical_alignment = WD_ALIGN_VERTICAL.CENTER
                p1 = cell.paragraphs[0]
                p1.alignment = WD_TABLE_ALIGNMENT.CENTER
                run = p1.add_run()
                generate_barcode(barcode)
                run.add_picture('Barcodes/'+ str(barcode)+".png"
                                ,width=Inches(1.60))
                p2 = cell.add_paragraph(name + "\n" + "$" + ('%.2f' % price))
                p2.alignment = WD_TABLE_ALIGNMENT.CENTER
    
                data_index +=1
                cell._tc.get_or_add_tcPr().append(shading_elm_1)
            if counter == 7:
                counter = 0
            counter +=1
    
            
    #row = table.rows[0].cells
    #row[0].vertical_alignment = WD_ALIGN_VERTICAL.CENTER
    #p1 = row[0].paragraphs[0]
    #run = p1.add_run()
    #run.add_picture(image,width=Inches(1.60))
    #p2 = row[0].add_paragraph(name + "\n" + "$" + str(price))
    #p2.alignment = WD_TABLE_ALIGNMENT.CENTER

# %%
# Creates each table in document
def create_table(doc,df):
    table = doc.add_table(rows=8,cols=7)
    table.alignment = WD_TABLE_ALIGNMENT.LEFT
    table.style = "Table Grid"
    table.autofit = False
    set_table_dim(table)
    populate_table(table,df)

# %%
# Separates dataframe into 32 equal sections for each of the pages.
def list_df(df):
    length = df.shape[0]
    i = 0
    ls = []
    while i < length:
        try:
            temp_df = df.loc[i:i+31]
            ls.append(temp_df.reset_index(drop=True))
        except:
            temp_df = df.loc[i:,:]
            ls.append(temp_df.reset_index(drop=True))
        i +=32
    return ls

# %%
df = pd.read_excel('data.xlsx')
df = df.loc[:,['Barcode Lookup','Description1','Price']]
df.loc[:,'Price'] = df.loc[:,'Price'] * 0.75
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108 entries, 0 to 107
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Barcode Lookup  108 non-null    int64
#  1   Description1    108 non-null    object
#  2   Price           108 non-null    float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 2.7+ KB

# %%
doc = docx.Document()
style = doc.styles['Normal']
font = style.font
font.size = Pt(11)
font.name='Calibri'

# %%
data = list_df(df)
for d in data:
    print(d)
    create_table(doc,d)
print('File is Ready.')
# Out:
#     Barcode Lookup              Description1   Price
# 0     195699578913  BARELY BAGGIES SHORT 2.5   44.25
# 1     195699192317             CAP MW BOTTOM   59.25
# 2     195699192942           CAP MW ZIP NECK   66.75
# 3     195699193031           CAP MW ZIP NECK   66.75
# 4     195699193130           CAP MW ZIP NECK   66.75
# 5     195699577404       LW SYNCH SNAP-T P/O   96.75
# 6     195699008892        R2 TECHFACE JACKET  134.25
# 7     195699673304         ALPINE GUIDE PANT  186.75
# 8     195699673359         ALPINE GUIDE PANT  186.75
# 9     195699673434         ALPINE GUIDE PANT  186.75
# 10    195699673496         ALPINE GUIDE PANT  186.75
# 11    195699673564         ALPINE GUIDE PANT  186.75
# 12    195699673649         ALPINE GUIDE PANT  186.75
# 13    195699903364  BARELY BAGGIES SHORT 2.5   44.25
# 14    195699903388  BARELY BAGGIES SHORT 2.5   44.25
# 15    195699903395  BARELY BAGGIES SHORT 2.5   44.25
# 16    195699903418  BARELY BAGGIES SHORT 2.5   44.25
# 17    195699903425  BARELY BAGGIES SHORT 2.5   44.25
# 18    195699905849  BARELY BAGGIES SHORT 2.5   44.25
# 19    195699905870  BARELY BAGGIES SHORT 2.5   44.25
# 20    195699905900  BARELY BAGGIES SHORT 2.5   44.25
# 21    195699905931  BARELY BAGGIES SHORT 2.5   44.25
# 22    195699905955  BARELY BAGGIES SHORT 2.5   44.25
# 23    195699993006  BARELY BAGGIES SHORT 2.5   44.25
# 24    195699993013  BARELY BAGGIES SHORT 2.5   44.25
# 25    195699993020  BARELY BAGGIES SHORT 2.5   44.25
# 26    194187801687    BETTER SWEATER 1/4 ZIP  104.25
# 27    191743866708     BETTER SWEATER JACKET  119.25
# 28    191743866753     BETTER SWEATER JACKET  119.25
# 29    191743866791     BETTER SWEATER JACKET  119.25
# 30    191743866821     BETTER SWEATER JACKET  119.25
# 31    195699691919             CAP MW BOTTOM   59.25
# 8
#     Barcode Lookup                      Description1   Price
# 0     195699691926                     CAP MW BOTTOM   59.25
# 1     195699691933                     CAP MW BOTTOM   59.25
# 2     195699691940                     CAP MW BOTTOM   59.25
# 3     195699691957                     CAP MW BOTTOM   59.25
# 4     195699692459                   CAP MW ZIP NECK   66.75
# 5     195699692473                   CAP MW ZIP NECK   66.75
# 6     195699692503                   CAP MW ZIP NECK   66.75
# 7     195699692534                   CAP MW ZIP NECK   66.75
# 8     195699692565                   CAP MW ZIP NECK   66.75
# 9     195699950016                DOWN SWEATER HOODY  246.75
# 10    195699950047                DOWN SWEATER HOODY  246.75
# 11    195699950078                DOWN SWEATER HOODY  246.75
# 12    195699950092                DOWN SWEATER HOODY  246.75
# 13    195699963467                 DOWN SWEATER VEST  171.75
# 14    195699963498                 DOWN SWEATER VEST  171.75
# 15    195699963528                 DOWN SWEATER VEST  171.75
# 16    195699963559                 DOWN SWEATER VEST  171.75
# 17    195699719859  L/S CAP COOL DAILY GRAPHIC SHIRT   44.25
# 18    195699719873  L/S CAP COOL DAILY GRAPHIC SHIRT   44.25
# 19    195699719897  L/S CAP COOL DAILY GRAPHIC SHIRT   44.25
# 20    195699719910  L/S CAP COOL DAILY GRAPHIC SHIRT   44.25
# 21    195699698857          L/S CAP COOL DAILY SHIRT   44.25
# 22    195699698901          L/S CAP COOL DAILY SHIRT   44.25
# 23    195699698932          L/S CAP COOL DAILY SHIRT   44.25
# 24    195699698970          L/S CAP COOL DAILY SHIRT   44.25
# 25    195699824911               LW SYNCH SNAP-T P/O  104.25
# 26    195699824942               LW SYNCH SNAP-T P/O  104.25
# 27    195699824980               LW SYNCH SNAP-T P/O  104.25
# 28    195699904477             MICRODINI 1/2 ZIP P/O   96.75
# 29    195699904484             MICRODINI 1/2 ZIP P/O   96.75
# 30    195699904491             MICRODINI 1/2 ZIP P/O   96.75
# 31    195699904507             MICRODINI 1/2 ZIP P/O   96.75
# 8
#     Barcode Lookup                 Description1     Price
# 0     195699904514        MICRODINI 1/2 ZIP P/O   96.7500
# 1     195699599574               PACK OUT TIGHT   89.2500
# 2     195699599604               PACK OUT TIGHT   89.2500
# 3     195699665507        R1 AIR FULL ZIP HOODY  134.2500
# 4     195699665514        R1 AIR FULL ZIP HOODY  134.2500
# 5     195699665521        R1 AIR FULL ZIP HOODY  134.2500
# 6     195699665538        R1 AIR FULL ZIP HOODY  134.2500
# 7     195699665545        R1 AIR FULL ZIP HOODY  134.2500
# 8     195699671263        R1 AIR FULL ZIP HOODY  134.2500
# 9     195699671287        R1 AIR FULL ZIP HOODY  134.2500
# 10    195699671300        R1 AIR FULL ZIP HOODY  134.2500
# 11    195699673663              R1 AIR ZIP NECK   96.7500
# 12    195699673724              R1 AIR ZIP NECK   96.7500
# 13    195699673779              R1 AIR ZIP NECK   96.7500
# 14    195699590243            R1 DAILY ZIP NECK   96.7500
# 15    195699590373            R1 DAILY ZIP NECK   96.7500
# 16    195699590540            R1 DAILY ZIP NECK   96.7500
# 17    195699677784           R2 TECHFACE JACKET  134.2500
# 18    195699677838           R2 TECHFACE JACKET  134.2500
# 19    195699677883           R2 TECHFACE JACKET  134.2500
# 20    195699677944           R2 TECHFACE JACKET  134.2500
# 21    195699677999           R2 TECHFACE JACKET  134.2500
# 22    194187117252         TERRAVIA ALPINE PANT  111.7500
# 23    194187117603         TERRAVIA ALPINE PANT  111.7500
# 24    195699705654         TERRAVIA ALPINE PANT  111.7500
# 25    195699705661         TERRAVIA ALPINE PANT  111.7500
# 26    195699705678         TERRAVIA ALPINE PANT  111.7500
# 27    195699705692         TERRAVIA ALPINE PANT   50.2425
# 28    195699683471  TORRENTSHELL 3L RAIN JACKET  134.2500
# 29    195699683495  TORRENTSHELL 3L RAIN JACKET  134.2500
# 30    195699683525  TORRENTSHELL 3L RAIN JACKET  134.2500
# 31    195699683556  TORRENTSHELL 3L RAIN JACKET  134.2500
# 8
#     Barcode Lookup                 Description1   Price
# 0     196924030114  TORRENTSHELL 3L RAIN JACKET  134.25
# 1     196924030176  TORRENTSHELL 3L RAIN JACKET  134.25
# 2     195699683495  TORRENTSHELL 3L RAIN JACKET  134.25
# 3     195699683471  TORRENTSHELL 3L RAIN JACKET  134.25
# 4     195699683556  TORRENTSHELL 3L RAIN JACKET  134.25
# 5     196924022065  TORRENTSHELL 3L RAIN JACKET  134.25
# 6     196924022027  TORRENTSHELL 3L RAIN JACKET  134.25
# 7     196924022102  TORRENTSHELL 3L RAIN JACKET  134.25
# 8     195699684669  TORRENTSHELL 3L RAIN JACKET  134.25
# 9     195699684652  TORRENTSHELL 3L RAIN JACKET  134.25
# 10    195699684645  TORRENTSHELL 3L RAIN JACKET  134.25
# 11    195699684638  TORRENTSHELL 3L RAIN JACKET  134.25
# 8
# File is Ready.

# %%
set_section_margins(doc)

# %%
doc.save('tags.docx')

# %%
# Removes all images of barcodes created to save memory
filelist = glob.glob(os.path.join('Barcodes', "*.png"))
for f in filelist:
    os.remove(f)
